# %%
import pandas as pd
import numpy as np

# %%
#download the class movie reviews from here:
#https://docs.google.com/spreadsheets/d/17rCJzmWxqvAu9rkpkgt4ToccIlY4A1Ffuu1W9X3B8Ag/
#then read that in as a pandas dataframe

# %%
M = pd.read_csv("movie_reviews.csv", index_col='Name')

# %%
M
# Out:
#                      American Sniper  The Hunger Games: Mockingjay - Part 1  \
# Name
# Aarti Jaiswal                    4.0                                    NaN
# Aditya Dharmasagar               5.0                                    NaN
# Adrian Cavallaris                NaN                                    4.0
# Ahmed Muheebuddin                5.0                                    NaN
# Aishwarya reddy                  NaN                                    3.0
# Akhilesh                         NaN                                    NaN
# Andrew Webb                      4.0                                    3.0
# Anirudh                          3.0                                    4.0
# Anirudh Thota                    NaN                                    3.0
# anurag                           4.0                                    NaN
# Anusha Putta                     NaN                                    NaN
# Arun Vedere                      4.0                                    3.0
# Ashutosh Sureka                  5.0                                    4.0
# Aswini kumar                     4.0                                    4.0
# azam                             4.0                                    NaN
# Benjamin Baysinger               5.0                                    4.0
# Bhuvana Posina                   5.0                                    4.0
# Bradley Brubaker                 NaN                                    1.0
# Brant Mullinix                   NaN                                    4.0
# Charlie                          NaN                                    2.0
# David Huang                      5.0                                    NaN
# David Reyling                    NaN                                    1.0
# Evan Piercy                      4.0                                    NaN
# Graham Bullard                   3.0                                    2.0
# Greg Werner                      5.0                                    3.0
# Harish Kallianpur                5.0                                    3.0
# Heather Sanders                  NaN                                    3.0
# HJ SONG                          NaN                                    2.0
# J A Barnes                       NaN                                    3.0
# Jake Metzger                     NaN                                    NaN
# ...                              ...                                    ...
# Chaitanya Varma                  4.0                                    1.0
# Evan Thompson                    NaN                                    3.0
# Jayesh Fulzele                   4.5                                    3.0
# Aman Chandrakar                  4.0                                    3.5
# Kalyan Chand                     4.0                                    4.0
# Somya Gupta                      NaN                                    3.5
# Gaurav Khandave                  4.0                                    4.0
# Ali Touseef                      4.0                                    3.5
# Gaurav Karale                    5.0                                    4.0
# Aditi Lele                       NaN                                    3.0
# Ugo Obialo                       5.0                                    NaN
# Rohit Ukirde                     5.0                                    4.0
# Megha Sogani                     5.0                                    NaN
# Craig Gordon                     NaN                                    NaN
# Daniel Lee                       NaN                                    4.0
# Trisha Moyer                     4.0                                    5.0
# Vikram Reddy                     NaN                                    3.0
# Camron  Khan                     4.0                                    4.0
# Prachi Jain                      NaN                                    3.0
# Randy Moyers                     4.0                                    4.0
# Sailokesh                        5.0                                    4.0
# Jemberie A                       5.0                                    2.0
# Anupom Syam                      NaN                                    NaN
# Supehr Zangeneh                  4.0                                    4.0
# Karan Deepak Kanwar              5.0                                    NaN
# Mark Dang                        NaN                                    NaN
# Jensen Hou                       5.0                                    3.0
# Moses Stanley                    5.0                                    NaN
# Vibhor Sharma                    5.0                                    3.0
# Jeremy Embalabala                5.0                                    4.0
#
#                      Guardians of the Galaxy  The Lego Movie  The Hobbit  \
# Name
# Aarti Jaiswal                            NaN             NaN         4.0
# Aditya Dharmasagar                       NaN             4.0         5.0
# Adrian Cavallaris                        3.0             NaN         4.0
# Ahmed Muheebuddin                        4.0             NaN         3.0
# Aishwarya reddy                          4.0             3.0         4.0
# Akhilesh                                 4.0             3.0         5.0
# Andrew Webb                              4.0             3.0         3.0
# Anirudh                                  5.0             3.0         5.0
# Anirudh Thota                            4.0             3.0         3.0
# anurag                                   NaN             NaN         3.0
# Anusha Putta                             NaN             NaN         4.0
# Arun Vedere                              4.0             3.0         5.0
# Ashutosh Sureka                          5.0             5.0         5.0
# Aswini kumar                             5.0             NaN         NaN
# azam                                     3.0             NaN         5.0
# Benjamin Baysinger                       5.0             5.0         3.0
# Bhuvana Posina                           4.0             5.0         3.0
# Bradley Brubaker                         5.0             5.0         5.0
# Brant Mullinix                           4.0             4.0         5.0
# Charlie                                  3.0             NaN         3.0
# David Huang                              4.0             NaN         NaN
# David Reyling                            NaN             NaN         1.0
# Evan Piercy                              NaN             4.0         NaN
# Graham Bullard                           4.0             3.0         4.0
# Greg Werner                              3.0             NaN         NaN
# Harish Kallianpur                        NaN             NaN         5.0
# Heather Sanders                          NaN             1.0         3.0
# HJ SONG                                  3.0             4.0         4.0
# J A Barnes                               4.0             NaN         4.0
# Jake Metzger                             4.0             NaN         NaN
# ...                                      ...             ...         ...
# Chaitanya Varma                          4.0             4.0         5.0
# Evan Thompson                            4.0             4.0         4.0
# Jayesh Fulzele                           4.5             4.0         3.0
# Aman Chandrakar                          NaN             4.0         4.0
# Kalyan Chand                             3.0             NaN         5.0
# Somya Gupta                              NaN             NaN         4.0
# Gaurav Khandave                          4.5             3.0         3.5
# Ali Touseef                              4.0             NaN         4.5
# Gaurav Karale                            4.0             3.0         4.0
# Aditi Lele                               5.0             5.0         5.0
# Ugo Obialo                               3.0             NaN         4.0
# Rohit Ukirde                             5.0             5.0         5.0
# Megha Sogani                             3.0             NaN         5.0
# Craig Gordon                             3.0             1.0         3.0
# Daniel Lee                               4.0             NaN         3.0
# Trisha Moyer                             NaN             5.0         NaN
# Vikram Reddy                             4.0             NaN         4.0
# Camron  Khan                             3.0             2.0         3.0
# Prachi Jain                              NaN             NaN         4.0
# Randy Moyers                             5.0             NaN         4.0
# Sailokesh                                4.0             3.0         5.0
# Jemberie A                               2.0             2.0         2.0
# Anupom Syam                              3.0             NaN         3.0
# Supehr Zangeneh                          NaN             NaN         NaN
# Karan Deepak Kanwar                      4.0             5.0         4.0
# Mark Dang                                4.0             NaN         2.0
# Jensen Hou                               3.0             5.0         3.0
# Moses Stanley                            3.0             NaN         3.0
# Vibhor Sharma                            4.0             NaN         4.0
# Jeremy Embalabala                        NaN             NaN         3.0
#
#                      Transformers  Malificent  Big Hero 6  Godzilla  \
# Name
# Aarti Jaiswal                 3.0         NaN         5.0       NaN
# Aditya Dharmasagar            4.0         4.0         NaN       4.0
# Adrian Cavallaris             2.0         NaN         NaN       NaN
# Ahmed Muheebuddin             NaN         NaN         NaN       NaN
# Aishwarya reddy               4.0         3.0         NaN       4.0
# Akhilesh                      4.0         NaN         NaN       NaN
# Andrew Webb                   2.0         NaN         4.0       3.0
# Anirudh                       3.0         5.0         NaN       4.0
# Anirudh Thota                 4.0         NaN         NaN       3.0
# anurag                        NaN         NaN         NaN       5.0
# Anusha Putta                  4.0         NaN         NaN       3.0
# Arun Vedere                   5.0         3.0         NaN       3.0
# Ashutosh Sureka               5.0         0.0         5.0       2.0
# Aswini kumar                  NaN         NaN         5.0       3.0
# azam                          NaN         NaN         NaN       NaN
# Benjamin Baysinger            2.0         2.0         4.0       4.0
# Bhuvana Posina                5.0         3.0         3.0       4.0
# Bradley Brubaker              4.0         NaN         NaN       4.0
# Brant Mullinix                3.0         NaN         NaN       NaN
# Charlie                       2.0         3.0         NaN       4.0
# David Huang                   5.0         NaN         NaN       4.0
# David Reyling                 1.0         NaN         NaN       3.0
# Evan Piercy                   4.0         NaN         NaN       NaN
# Graham Bullard                NaN         3.0         4.0       3.0
# Greg Werner                   4.0         4.0         NaN       NaN
# Harish Kallianpur             4.0         4.0         NaN       4.0
# Heather Sanders               3.0         3.0         4.0       NaN
# HJ SONG                       5.0         NaN         4.0       4.0
# J A Barnes                    4.0         NaN         NaN       NaN
# Jake Metzger                  2.0         3.0         NaN       2.0
# ...                           ...         ...         ...       ...
# Chaitanya Varma               4.0         3.5         4.0       3.0
# Evan Thompson                 2.0         NaN         5.0       NaN
# Jayesh Fulzele                2.0         2.0         3.0       4.0
# Aman Chandrakar               4.0         3.0         5.0       3.5
# Kalyan Chand                  5.0         3.0         5.0       4.0
# Somya Gupta                   5.0         NaN         5.0       3.5
# Gaurav Khandave               3.0         3.0         4.5       4.0
# Ali Touseef                   5.0         3.5         NaN       2.0
# Gaurav Karale                 4.0         3.0         3.0       4.0
# Aditi Lele                    3.0         4.0         1.0       5.0
# Ugo Obialo                    3.0         NaN         NaN       NaN
# Rohit Ukirde                  3.0         3.0         2.0       1.0
# Megha Sogani                  4.0         NaN         1.0       5.0
# Craig Gordon                  3.0         NaN         3.0       NaN
# Daniel Lee                    3.0         2.0         NaN       NaN
# Trisha Moyer                  2.0         NaN         5.0       NaN
# Vikram Reddy                  3.0         3.0         4.0       3.0
# Camron  Khan                  NaN         NaN         NaN       3.0
# Prachi Jain                   2.5         NaN         2.0       3.0
# Randy Moyers                  3.0         NaN         NaN       3.0
# Sailokesh                     4.0         NaN         NaN       4.0
# Jemberie A                    3.0         NaN         NaN       2.0
# Anupom Syam                   3.0         NaN         5.0       3.0
# Supehr Zangeneh               NaN         NaN         NaN       NaN
# Karan Deepak Kanwar           5.0         NaN         NaN       5.0
# Mark Dang                     2.0         3.0         5.0       NaN
# Jensen Hou                    2.0         NaN         5.0       3.0
# Moses Stanley                 4.0         NaN         NaN       4.0
# Vibhor Sharma                 3.0         3.0         4.0       3.0
# Jeremy Embalabala             3.0         NaN         NaN       NaN
#
#                      Interstellar  How to Train your Dragon 2  Gone Girl  \
# Name
# Aarti Jaiswal                 NaN                         NaN        4.0
# Aditya Dharmasagar            5.0                         5.0        5.0
# Adrian Cavallaris             NaN                         NaN        NaN
# Ahmed Muheebuddin             NaN                         NaN        NaN
# Aishwarya reddy               4.0                         3.0        5.0
# Akhilesh                      5.0                         NaN        3.0
# Andrew Webb                   4.0                         3.0        4.0
# Anirudh                       NaN                         NaN        2.0
# Anirudh Thota                 4.0                         3.0        NaN
# anurag                        NaN                         3.0        NaN
# Anusha Putta                  NaN                         NaN        5.0
# Arun Vedere                   5.0                         4.0        NaN
# Ashutosh Sureka               3.0                         5.0        3.0
# Aswini kumar                  5.0                         4.0        NaN
# azam                          NaN                         NaN        NaN
# Benjamin Baysinger            4.0                         4.0        5.0
# Bhuvana Posina                5.0                         3.0        5.0
# Bradley Brubaker              NaN                         4.0        NaN
# Brant Mullinix                5.0                         3.0        3.0
# Charlie                       5.0                         2.0        NaN
# David Huang                   5.0                         NaN        NaN
# David Reyling                 NaN                         NaN        NaN
# Evan Piercy                   5.0                         NaN        2.0
# Graham Bullard                4.0                         NaN        4.0
# Greg Werner                   5.0                         4.0        5.0
# Harish Kallianpur             5.0                         4.0        NaN
# Heather Sanders               NaN                         3.0        NaN
# HJ SONG                       5.0                         5.0        NaN
# J A Barnes                    NaN                         3.0        NaN
# Jake Metzger                  NaN                         NaN        5.0
# ...                           ...                         ...        ...
# Chaitanya Varma               5.0                         4.0        5.0
# Evan Thompson                 NaN                         4.0        NaN
# Jayesh Fulzele                5.0                         4.0        5.0
# Aman Chandrakar               4.5                         5.0        5.0
# Kalyan Chand                  5.0                         5.0        5.0
# Somya Gupta                   5.0                         4.0        NaN
# Gaurav Khandave               5.0                         4.5        5.0
# Ali Touseef                   5.0                         4.0        NaN
# Gaurav Karale                 5.0                         4.0        4.0
# Aditi Lele                    5.0                         5.0        5.0
# Ugo Obialo                    5.0                         4.0        NaN
# Rohit Ukirde                  5.0                         3.0        3.0
# Megha Sogani                  4.0                         2.0        4.0
# Craig Gordon                  2.0                         4.0        NaN
# Daniel Lee                    4.0                         NaN        5.0
# Trisha Moyer                  NaN                         4.0        NaN
# Vikram Reddy                  5.0                         4.0        4.0
# Camron  Khan                  4.0                         NaN        4.0
# Prachi Jain                   5.0                         4.0        4.0
# Randy Moyers                  4.0                         3.0        NaN
# Sailokesh                     5.0                         3.0        NaN
# Jemberie A                    NaN                         NaN        NaN
# Anupom Syam                   4.0                         4.0        4.0
# Supehr Zangeneh               NaN                         NaN        NaN
# Karan Deepak Kanwar           4.0                         3.0        4.0
# Mark Dang                     5.0                         NaN        NaN
# Jensen Hou                    5.0                         4.0        4.0
# Moses Stanley                 5.0                         NaN        NaN
# Vibhor Sharma                 5.0                         3.0        5.0
# Jeremy Embalabala             NaN                         NaN        NaN
#
#                      Divergent  The Fault in Our Stars  Unbroken  \
# Name
# Aarti Jaiswal              NaN                     NaN       NaN
# Aditya Dharmasagar         4.0                     4.0       NaN
# Adrian Cavallaris          4.0                     NaN       NaN
# Ahmed Muheebuddin          NaN                     NaN       NaN
# Aishwarya reddy            NaN                     4.0       NaN
# Akhilesh                   NaN                     NaN       NaN
# Andrew Webb                2.0                     3.0       NaN
# Anirudh                    3.0                     4.0       NaN
# Anirudh Thota              NaN                     NaN       NaN
# anurag                     3.0                     NaN       NaN
# Anusha Putta               4.0                     NaN       NaN
# Arun Vedere                NaN                     NaN       NaN
# Ashutosh Sureka            3.0                     2.0       2.0
# Aswini kumar               NaN                     NaN       NaN
# azam                       NaN                     NaN       NaN
# Benjamin Baysinger         1.0                     4.0       3.0
# Bhuvana Posina             3.0                     3.0       3.0
# Bradley Brubaker           3.0                     NaN       NaN
# Brant Mullinix             NaN                     NaN       NaN
# Charlie                    2.0                     3.0       NaN
# David Huang                NaN                     NaN       NaN
# David Reyling              NaN                     NaN       NaN
# Evan Piercy                NaN                     NaN       NaN
# Graham Bullard             NaN                     NaN       4.0
# Greg Werner                4.0                     NaN       NaN
# Harish Kallianpur          3.0                     NaN       NaN
# Heather Sanders            3.0                     3.0       5.0
# HJ SONG                    NaN                     NaN       5.0
# J A Barnes                 3.0                     NaN       NaN
# Jake Metzger               NaN                     NaN       NaN
# ...                        ...                     ...       ...
# Chaitanya Varma            4.0                     4.0       3.0
# Evan Thompson              4.0                     NaN       NaN
# Jayesh Fulzele             3.0                     NaN       3.0
# Aman Chandrakar            3.5                     3.0       NaN
# Kalyan Chand               3.0                     NaN       NaN
# Somya Gupta                NaN                     NaN       4.0
# Gaurav Khandave            NaN                     NaN       5.0
# Ali Touseef                5.0                     NaN       3.5
# Gaurav Karale              4.0                     5.0       5.0
# Aditi Lele                 NaN                     4.0       NaN
# Ugo Obialo                 NaN                     NaN       NaN
# Rohit Ukirde               2.0                     5.0       3.0
# Megha Sogani               3.0                     1.0       4.0
# Craig Gordon               NaN                     NaN       NaN
# Daniel Lee                 3.0                     NaN       NaN
# Trisha Moyer               NaN                     NaN       NaN
# Vikram Reddy               NaN                     4.0       NaN
# Camron  Khan               NaN                     NaN       4.0
# Prachi Jain                3.0                     5.0       NaN
# Randy Moyers               4.0                     NaN       NaN
# Sailokesh                  NaN                     4.0       NaN
# Jemberie A                 NaN                     NaN       NaN
# Anupom Syam                NaN                     NaN       NaN
# Supehr Zangeneh            NaN                     NaN       NaN
# Karan Deepak Kanwar        NaN                     5.0       NaN
# Mark Dang                  NaN                     NaN       NaN
# Jensen Hou                 4.0                     NaN       NaN
# Moses Stanley              NaN                     NaN       NaN
# Vibhor Sharma              4.0                     3.0       4.0
# Jeremy Embalabala          NaN                     NaN       NaN
#
#                      300: Rise of an Empire
# Name
# Aarti Jaiswal                           NaN
# Aditya Dharmasagar                      5.0
# Adrian Cavallaris                       NaN
# Ahmed Muheebuddin                       NaN
# Aishwarya reddy                         3.0
# Akhilesh                                5.0
# Andrew Webb                             3.0
# Anirudh                                 2.0
# Anirudh Thota                           4.0
# anurag                                  5.0
# Anusha Putta                            NaN
# Arun Vedere                             1.0
# Ashutosh Sureka                         4.0
# Aswini kumar                            4.0
# azam                                    NaN
# Benjamin Baysinger                      2.0
# Bhuvana Posina                          5.0
# Bradley Brubaker                        2.0
# Brant Mullinix                          4.0
# Charlie                                 2.0
# David Huang                             5.0
# David Reyling                           NaN
# Evan Piercy                             2.0
# Graham Bullard                          3.0
# Greg Werner                             4.0
# Harish Kallianpur                       3.0
# Heather Sanders                         NaN
# HJ SONG                                 5.0
# J A Barnes                              NaN
# Jake Metzger                            3.0
# ...                                     ...
# Chaitanya Varma                         4.0
# Evan Thompson                           NaN
# Jayesh Fulzele                          2.0
# Aman Chandrakar                         3.0
# Kalyan Chand                            3.0
# Somya Gupta                             4.0
# Gaurav Khandave                         4.5
# Ali Touseef                             5.0
# Gaurav Karale                           5.0
# Aditi Lele                              NaN
# Ugo Obialo                              NaN
# Rohit Ukirde                            2.0
# Megha Sogani                            NaN
# Craig Gordon                            4.0
# Daniel Lee                              5.0
# Trisha Moyer                            NaN
# Vikram Reddy                            2.0
# Camron  Khan                            NaN
# Prachi Jain                             4.0
# Randy Moyers                            3.0
# Sailokesh                               3.0
# Jemberie A                              NaN
# Anupom Syam                             5.0
# Supehr Zangeneh                         4.0
# Karan Deepak Kanwar                     4.0
# Mark Dang                               3.0
# Jensen Hou                              NaN
# Moses Stanley                           4.0
# Vibhor Sharma                           5.0
# Jeremy Embalabala                       4.0
#
# [124 rows x 16 columns]

# %%
def pearson(s1, s2):
    """Take two pd.Series objects and return a pearson correlation."""
    s1_c = s1 - s1.mean()
    s2_c = s2 - s2.mean()
    return np.sum(s1_c * s2_c) / np.sqrt(np.sum(s1_c ** 2) * np.sum(s2_c ** 2))

# %%
def get_recs(movie_name, M, num):

    import numpy as np
    reviews = []
    for title in M.columns:
        if title == movie_name:
            continue
        cor = pearson(M[movie_name], M[title])
        if np.isnan(cor):
            continue
        else:
            reviews.append((title, cor))
    
    reviews.sort(key=lambda tup: tup[1], reverse=True)
    return reviews[:num]

# %% [markdown]
# ###Question 1:  What movie is most Similar to 'The fault in our stars' (60 pts)

# %%
get_recs('The Fault in Our Stars', M, 1)
# Out:
# [('Malificent', 0.20279670863265634)]

# %% [markdown]
# ###Question 2:  Which movie(s) would you most like to see, based on your classmates experience? (40 pts)

# %%
#HINTS...

#the movies I've seen
my_ratings = M.ix['Vibhor Sharma'].dropna()
#the movie I've rated the highest
my_ratings.sort(ascending=False)
#the name of the movie I've rated the highest
fav_movie = my_ratings.index[0]
# Out:
# C:\Users\abcd\Anaconda3\lib\site-packages\ipykernel\__main__.py:6: FutureWarning: sort is deprecated, use sort_values(inplace=True) for INPLACE sorting

# %%
fav_movie
# Out:
# '300: Rise of an Empire'

# %%
get_recs(fav_movie, M, 1)
# Out:
# [('Divergent', 0.30066335497916058)]

# %% [markdown]
# ###Question 3: Bonus Question...  For all the movies you haven't seen, can you predict how you'd rate them using your the class reviews? (10 pts)

# %%
notviewed = M.ix['Vibhor Sharma']
notviewed.sort()
for i in range(0, notviewed.count(), 1):
    notviewed.drop(notviewed.index[0], inplace=True)
# Out:
# C:\Users\abcd\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: sort is deprecated, use sort_values(inplace=True) for INPLACE sorting
#   from ipykernel import kernelapp as app

# %%
notviewed
# Out:
# The Lego Movie   NaN
# Name: Vibhor Sharma, dtype: float64

# %%
print ("Pearson Correlation coefficient of :")
a= []
for i in range(0, M.shape[0], 1): 
    cor=pearson(M.ix[79], M.ix[i])
    print ("(" + M.index[79] + " , " + M.index[i] + ") :", cor)
    a.append(cor)
# Out:
# Pearson Correlation coefficient of :
# (Fred Young , Aarti Jaiswal) : 0.504382204732
# (Fred Young , Aditya Dharmasagar) : 0.363376187334
# (Fred Young , Adrian Cavallaris) : 0.652072130504
# (Fred Young , Ahmed Muheebuddin) : 0.0
# (Fred Young , Aishwarya reddy) : 0.161860618514
# (Fred Young , Akhilesh) : -0.310057474275
# (Fred Young , Andrew Webb) : 0.48260614178
# (Fred Young , Anirudh) : -0.158583122349
# (Fred Young , Anirudh Thota) : -0.359656091165
# (Fred Young , anurag) : -0.00954272618899
# (Fred Young , Anusha Putta) : 0.474712663278
# (Fred Young , Arun Vedere) : -0.335053612867
# (Fred Young , Ashutosh Sureka) : -0.224562785863
# (Fred Young , Aswini kumar) : -0.0392491141014
# (Fred Young , azam) : 0.0
# (Fred Young , Benjamin Baysinger) : 0.411649577365
# (Fred Young , Bhuvana Posina) : -0.0349962818426
# (Fred Young , Bradley Brubaker) : -0.286720297418
# (Fred Young , Brant Mullinix) : 0.00421704499474
# (Fred Young , Charlie) : 0.0602105559095
# (Fred Young , David Huang) : -0.181688093667
# (Fred Young , David Reyling) : 0.0969003166223
# (Fred Young , Evan Piercy) : -0.505602415755
# (Fred Young , Graham Bullard) : -0.0394229584211
# (Fred Young , Greg Werner) : 0.128895188163
# (Fred Young , Harish Kallianpur) : -0.171297177457
# (Fred Young , Heather Sanders) : 0.0154711826721
# (Fred Young , HJ SONG) : -0.384610285708
# (Fred Young , J A Barnes) : -0.445372661388
# (Fred Young , Jake Metzger) : 0.765110763684
# (Fred Young , James Goodpasture) : 0.46939579369
# (Fred Young , Jared Knowles) : -0.0229819279888
# (Fred Young , Jessica Fong) : 0.145552210596
# (Fred Young , Jonathan Doll) : 0.631898547749
# (Fred Young , Josna Rajan) : 0.0228905481916
# (Fred Young , krishna sai) : -0.307844284616
# (Fred Young , M A Nissar) : -0.212297956974
# (Fred Young , Maheshwar Reddy) : 0.128568012971
# (Fred Young , Manideep Maddipatla) : -0.181277162439
# (Fred Young , Melanie Klein) : 0.330547470703
# (Fred Young , Michael Cooper) : 0.474712663278
# (Fred Young , Mike) : -0.0404805906971
# (Fred Young , Olumuyiwa Durojaiye) : -0.356904171838
# (Fred Young , Onsiri Tapsarn) : nan
# (Fred Young , Pavithra Shetty) : -0.53767323683
# (Fred Young , Rajesh Kinkirla) : -0.395669954498
# (Fred Young , Ryan Hansen) : 0.277963273633
# (Fred Young , Jordan Hoover) : 0.0861023946192
# (Fred Young , sai bhargav musuluri) : 0.0140734992195
# (Fred Young , Sai Sampath) : 0.161860618514
# (Fred Young , Sai Yallapragada) : -0.0839181358297
# (Fred Young , saikiran reddy) : -0.210094833431
# (Fred Young , sandeep katragadda) : -0.145436967339
# (Fred Young , Sara Collins) : 0.102778306474
# (Fred Young , Shannon Morrison) : -0.302813489445
# (Fred Young , Shiva rama raju Chekuri) : -0.0657372256983
# (Fred Young , siddanth sudarshan) : 0.00219925273291
# (Fred Young , Sina Tuy) : 0.386703154884
# (Fred Young , Sohaib Ahmed) : 0.404836319495
# (Fred Young , solomon choppara) : -0.242250791556
# (Fred Young , Sundar Prasad) : -0.565280685608
# (Fred Young , Sunil Nandikanti) : -0.27555387605
# (Fred Young , surya chandra reddy kovvuri) : -0.076038478365
# (Fred Young , Susan Huang) : 0.499719831877
# (Fred Young , Suyendra) : 0.230708332647
# (Fred Young , Syed Abbas Hussaini) : -0.406904417533
# (Fred Young , Syed Farzan) : 0.0601808140714
# (Fred Young , Thomas Podlipni) : 0.456238990763
# (Fred Young , Trudy Kline) : -0.203969279441
# (Fred Young , Tyler Vitanova) : 0.244322302703
# (Fred Young , ugesh reddy challa) : -0.0190022741124
# (Fred Young , veerendra battula) : 0.19064919341
# (Fred Young , Venkatesh Komma) : -0.110065220589
# (Fred Young , Violeta Lee Fay) : -0.363376187334
# (Fred Young , Yinka Adeyemo) : nan
# (Fred Young , Sai Sharan Vellala) : -0.450020881453
# (Fred Young , Andrew Peabody) : -0.0579391684354
# (Fred Young , Matthew Dearing) : -0.0500391083361
# (Fred Young , Matthew Murphy) : 0.0196491338381
# (Fred Young , Fred Young) : 1.0
# (Fred Young , Rohit Tatar) : -0.475435400433
# (Fred Young , Pratik Belhekar) : -0.265160833083
# (Fred Young , Chris DiBello) : -0.114312837508
# (Fred Young , Rajat Hatwar) : -0.150883749223
# (Fred Young , Chaitanya Kusurkar) : -0.457201317168
# (Fred Young , Ramya Doddi) : -0.276044170601
# (Fred Young , Amy Camp) : -0.121970326569
# (Fred Young , Poojitha Polusani) : 0.181337838248
# (Fred Young , Tushar Borole) : -0.0663431115543
# (Fred Young , Roopa Maddikunta) : -0.448363656373
# (Fred Young , Josh Garrett) : -0.228027289348
# (Fred Young , Koushal Yeginwar) : 0.107248997281
# (Fred Young , Rajesh Jaiswal) : -0.494801954163
# (Fred Young , Shreya Kulkarni) : 0.0786828577677
# (Fred Young , Chaitanya Varma) : -0.0788954666428
# (Fred Young , Evan Thompson) : 0.429393760179
# (Fred Young , Jayesh Fulzele) : 0.44077019141
# (Fred Young , Aman Chandrakar) : 0.184455224943
# (Fred Young , Kalyan Chand) : -0.0404327695455
# (Fred Young , Somya Gupta) : -0.434736230029
# (Fred Young , Gaurav Khandave) : 0.488524429347
# (Fred Young , Ali Touseef) : -0.263466764659
# (Fred Young , Gaurav Karale) : -0.0301442842624
# (Fred Young , Aditi Lele) : 0.207973158407
# (Fred Young , Ugo Obialo) : 0.335672543319
# (Fred Young , Rohit Ukirde) : 0.00792951849619
# (Fred Young , Megha Sogani) : -0.0533201941775
# (Fred Young , Craig Gordon) : -0.0240038409218
# (Fred Young , Daniel Lee) : 0.499437281157
# (Fred Young , Trisha Moyer) : 0.687529602332
# (Fred Young , Vikram Reddy) : 0.166190492919
# (Fred Young , Camron  Khan) : 0.254115292721
# (Fred Young , Prachi Jain) : 0.264251979368
# (Fred Young , Randy Moyers) : 0.259026332671
# (Fred Young , Sailokesh) : -0.0513891532371
# (Fred Young , Jemberie A) : -0.181283892735
# (Fred Young , Anupom Syam) : 0.332298864294
# (Fred Young , Supehr Zangeneh) : nan
# (Fred Young , Karan Deepak Kanwar) : -0.323834460801
# (Fred Young , Mark Dang) : 0.317326469577
# (Fred Young , Jensen Hou) : 0.343962002487
# (Fred Young , Moses Stanley) : 0.0
# (Fred Young , Vibhor Sharma) : 0.322779745991
# (Fred Young , Jeremy Embalabala) : 0.366099952268

# %%
def pred_rate(x, a):
    """
    Takes two parameters 'x' and 'a'. 
    Where 'x' a list of rates given by classmates. 
    'a' is a array that has corresponding pearson correlation coefficientreturn (weights for the given rates).
    predicted rate is calculated as rate= (x[0]*a[0] + x[1]*a[1] +...+x[i]*a[i]) / (a[0]+a[1]+..+a[i]) 
    returns predicted rate 
    """
    j=0
    k=0
    for i in range(0, 23, 1): # as there are 23 rows(x.shape), range(0,23) 
        if x.irow(i)>0 and a[i]>0: 
            j= j+(a[i]*x.irow(i))
            k= k+a[i]
        else:
            continue
    return j/k

# %%
print ("Based on class ratings, the rating for the unwatched movie will be: ")
for i in range(0, notviewed.shape[0], 1):
    x=M[notviewed.index[i]]
    rate=pred_rate(x, a)
    print (notviewed.index[i] +": ", rate.round(1))
# Out:
# Based on class ratings, the rating for the unwatched movie will be:
# The Lego Movie:  3.8
# C:\Users\abcd\Anaconda3\lib\site-packages\ipykernel\__main__.py:12: FutureWarning: irow(i) is deprecated. Please use .iloc[i] or .iat[i]
# C:\Users\abcd\Anaconda3\lib\site-packages\ipykernel\__main__.py:13: FutureWarning: irow(i) is deprecated. Please use .iloc[i] or .iat[i]
